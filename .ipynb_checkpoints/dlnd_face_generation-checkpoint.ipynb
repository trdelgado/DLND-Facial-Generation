# %% [markdown]
# # Face Generation
# In this project, you'll use generative adversarial networks to generate new images of faces.
# ### Get the Data
# You'll be using two datasets in this project:
# - MNIST
# - CelebA
#
# Since the celebA dataset is complex and you're doing GANs in a project for the first time, we want you to test your neural network on MNIST before CelebA.  Running the GANs on MNIST will allow you to see how well your model trains sooner.
#
# If you're using [FloydHub](https://www.floydhub.com/), set `data_dir` to "/input" and use the [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## Explore the Data
# ### MNIST
# As you're aware, the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset contains images of handwritten digits. You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# The [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations.  Since you're going to be generating faces, you won't need the annotations.  You can view the first number of examples by changing `show_n_images`.

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## Preprocess the Data
# Since the project's main focus is on building the GANs, we'll preprocess the data for you.  The values of the MNIST and CelebA dataset will be in the range of -0.5 to 0.5 of 28x28 dimensional images.  The CelebA images will be cropped to remove parts of the image that don't include a face, then resized down to 28x28.
#
# The MNIST images are black and white images with a single [color channel](https://en.wikipedia.org/wiki/Channel_(digital_image%29) while the CelebA images have [3 color channels (RGB color channel)](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images).
# ## Build the Neural Network
# You'll build the components necessary to build a GANs by implementing the following functions below:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.1
# /Users/trdelgado/anaconda/envs/tensorflow3/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ### Input
# Implement the `model_inputs` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
# - Real input images placeholder with rank 4 using `image_width`, `image_height`, and `image_channels`.
# - Z input placeholder with rank 2 using `z_dim`.
# - Learning rate placeholder with rank 0.
#
# Return the placeholders in the following the tuple (tensor of real input images, tensor of z data)

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    inputs_real = tf.placeholder(tf.float32, (None, image_width, image_height, image_channels), name='input_real')
    inputs_z = tf.placeholder(tf.float32, (None, z_dim), name='input_z')
    learning_rate = tf.placeholder(tf.float32, name='learning_rate')

    return inputs_real, inputs_z, learning_rate

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Discriminator
# Implement `discriminator` to create a discriminator neural network that discriminates on `images`.  This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "discriminator" to allow the variables to be reused.  The function should return a tuple of (tensor output of the generator, tensor logits of the generator).

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param image: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    """
    # TODO: Implement Function
    with tf.variable_scope('discriminator', reuse=reuse):
        alpha = 0.2
        
        # Input convolutional layer
        x1 = tf.layers.conv2d(images, 64, 5, strides=2, padding='same')
        # Leaky Relu activation
        x1 = tf.maximum(alpha*x1, x1)
        
        # Second convolutional layer
        x2 = tf.layers.conv2d(x1, 128, 5, strides=2, padding='same')
        # Batch normalization
        x2 = tf.layers.batch_normalization(x2, training=True)
        # Leaky Relu activation
        x2 = tf.maximum(alpha*x2, x2)
        
        # Third convolutional layer
        x3 = tf.layers.conv2d(x2, 256, 5, strides=2, padding='same')
        # Batch normalization
        x3 = tf.layers.batch_normalization(x3, training=True)
        # Leaky Relu activation
        x3 = tf.maximum(alpha*x3, x3)
        
        # Reshape stack
        flat = tf.reshape(x3, (-1, 4*4*256))
        logits = tf.layers.dense(flat, 1)
        out = tf.nn.sigmoid(logits)

    return out, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Generator
# Implement `generator` to generate an image using `z`. This function should be able to reuse the variabes in the neural network.  Use [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) with a scope name of "generator" to allow the variables to be reused. The function should return the generated 28 x 28 x `out_channel_dim` images.

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    """
    # TODO: Implement Function
    with tf.variable_scope("generator", reuse = not is_train):
        alpha = 0.2
        # First fully connected layer
        x1 = tf.layers.dense(z, 7*7*256)
        # Reshape it to start the convolutional stack
        x1 = tf.reshape(x1, (-1, 7, 7, 256))
        # Batch normalization
        x1 = tf.layers.batch_normalization(x1, training=True)
        # Leaky Relu activation
        x1 = tf.maximum(alpha * x1, x1) # 4x4x512
        
        # Convolutional layer
        x2 = tf.layers.conv2d_transpose(x1, 128, 5, strides=2, padding='same')
        # Batch normalization
        x2 = tf.layers.batch_normalization(x2, training=is_train)
        # Leaky Relu activation
        x2 = tf.maximum(alpha * x2, x2) # 7x7x256
        
        # 2nd Convoutional layer
        x3 = tf.layers.conv2d_transpose(x2, 64, 5, strides=2, padding='same')
        # Batch normalization
        x3 = tf.layers.batch_normalization(x3, training=is_train)
        # Leaky Relu activation
        x3 = tf.maximum(alpha * x3, x3) # 14x14x128
        
        # Output layer
        logits = tf.layers.conv2d_transpose(x3, out_channel_dim, 3, strides=1, padding='same') # 28x28x3
        out = tf.tanh(logits)
    
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### Loss
# Implement `model_loss` to build the GANs for training and calculate the loss.  The function should return a tuple of (discriminator loss, generator loss).  Use the following functions you implemented:
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    """
    # TODO: Implement Function
    
    # Get generator and discriminator outputs
    gen_model = generator(input_z, out_channel_dim)
    dis_model_real, dis_logits_real = discriminator(input_real)
    dis_model_fake, dis_logits_fake = discriminator(gen_model, reuse=True)
    
    # Get the loss fake and real discriminator loss and add them to get the total discriminator loss
    dis_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=dis_logits_real, labels=tf.ones_like(dis_model_real)))
    dis_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=dis_logits_fake, labels=tf.zeros_like(dis_model_fake)))
    dis_loss = dis_loss_real + dis_loss_fake
    
    # Get the generator loss
    gen_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=dis_logits_fake, labels=tf.ones_like(dis_model_fake)))
    
    return dis_loss, gen_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### Optimization
# Implement `model_opt` to create the optimization operations for the GANs. Use [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) to get all the trainable variables.  Filter the variables with names that are in the discriminator and generator scope names.  The function should return a tuple of (discriminator training operation, generator training operation).

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    
    # Get weights and bias to update
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]
    all_update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
    
    g_update_ops = [var for var in all_update_ops if var.name.startswith('generator')]
    d_update_ops = [var for var in all_update_ops if var.name.startswith('discriminator')]
    
    # Optimize
    # The weights should be same for both real and fake data so we need to reuse the variables
    # Where the generator's and the discriminator's update ops are clearly distinguished
    # Source: https://discussions.udacity.com/t/project-5-net-not-training/246936/9
    with tf.control_dependencies(d_update_ops):
        d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
    with tf.control_dependencies(g_update_ops):
        g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)
    
    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Show Output
# Use this function to show the current output of the generator during training. It will help you determine how well the GANs is training.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### Train
# Implement `train` to build and train the GANs.  Use the following functions you implemented:
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# Use the `show_generator_output` to show `generator` output while you train. Running `show_generator_output` for every batch will drastically increase training time and increase the size of the notebook.  It's recommended to print the `generator` output every 100 batches.

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    
    # Get data shape and model inputs
    input_real, input_z, lr = model_inputs(data_shape[1], data_shape[2], data_shape[3], z_dim)
                
    # Get the loss values from the generator and discriminator
    d_loss, g_loss = model_loss(input_real, input_z, data_shape[3])
    
    # Get the generator and discriminator optimizers
    d_opt, g_opt = model_opt(d_loss, g_loss, learning_rate, beta1)
    
    samples, losses = [], []
    steps = 0
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                batch_images = batch_images*2.0
                # TODO: Train Model
                steps += 1
                
                # Sample random noise for the generator
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))
                
                # Run optimizers
                _ = sess.run(d_opt, feed_dict={input_real: batch_images, input_z: batch_z, lr: learning_rate})
                _ = sess.run(g_opt, feed_dict={input_z: batch_z, lr: learning_rate})
                _ = sess.run(g_opt, feed_dict={input_z: batch_z, lr: learning_rate})
                
                if steps % 10 == 0:
                    # At the end of each epoch, get the losses and print them out
                    train_loss_d = d_loss.eval({input_z: batch_z, input_real: batch_images})
                    train_loss_g = g_loss.eval({input_z: batch_z})
                    
                    print("Epoch {}/{}...".format(epoch_i+1, epochs), \
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    
                if steps % 100 == 0:  
                    # Output the 
                    show_generator_output(sess, 16, input_z, data_shape[3], data_image_mode)
                          
    return losses, samples

# %% [markdown]
# ### MNIST
# Test your GANs architecture on MNIST.  After 2 epochs, the GANs should be able to generate images that look like handwritten digits.  Make sure the loss of the generator is lower than the loss of the discriminator or close to 0.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.001
beta1 = 0.3


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 2.6520... Generator Loss: 3.3545
# Epoch 1/1... Discriminator Loss: 8.3399... Generator Loss: 7.7702
# Epoch 1/1... Discriminator Loss: 2.9021... Generator Loss: 0.0912
# Epoch 1/1... Discriminator Loss: 2.1363... Generator Loss: 0.2593
# Epoch 1/1... Discriminator Loss: 2.0574... Generator Loss: 0.2061
# Epoch 1/1... Discriminator Loss: 1.8554... Generator Loss: 0.2547
# Epoch 1/1... Discriminator Loss: 1.7703... Generator Loss: 0.3117
# Epoch 1/1... Discriminator Loss: 1.6421... Generator Loss: 0.4243
# Epoch 1/1... Discriminator Loss: 1.4981... Generator Loss: 0.4355
# Epoch 1/1... Discriminator Loss: 1.5987... Generator Loss: 0.6907
# Epoch 1/1... Discriminator Loss: 1.5593... Generator Loss: 0.7868
# Epoch 1/1... Discriminator Loss: 1.5460... Generator Loss: 0.8965
# Epoch 1/1... Discriminator Loss: 1.4348... Generator Loss: 0.7760
# Epoch 1/1... Discriminator Loss: 1.7627... Generator Loss: 0.2849
# Epoch 1/1... Discriminator Loss: 1.4977... Generator Loss: 0.4460
# Epoch 1/1... Discriminator Loss: 1.5800... Generator Loss: 0.3775
# Epoch 1/1... Discriminator Loss: 1.6845... Generator Loss: 0.3159
# Epoch 1/1... Discriminator Loss: 1.4048... Generator Loss: 0.5050
# Epoch 1/1... Discriminator Loss: 1.4958... Generator Loss: 0.4473
# Epoch 1/1... Discriminator Loss: 1.5450... Generator Loss: 0.4790
# Epoch 1/1... Discriminator Loss: 1.6198... Generator Loss: 1.0268
# Epoch 1/1... Discriminator Loss: 1.4740... Generator Loss: 0.7574
# Epoch 1/1... Discriminator Loss: 1.5016... Generator Loss: 0.7532
# Epoch 1/1... Discriminator Loss: 1.5952... Generator Loss: 0.9996
# Epoch 1/1... Discriminator Loss: 1.5040... Generator Loss: 1.0039
# Epoch 1/1... Discriminator Loss: 1.5641... Generator Loss: 0.9514
# Epoch 1/1... Discriminator Loss: 1.4868... Generator Loss: 0.7186
# Epoch 1/1... Discriminator Loss: 1.5945... Generator Loss: 0.9793
# Epoch 1/1... Discriminator Loss: 1.5448... Generator Loss: 1.1749
# Epoch 1/1... Discriminator Loss: 1.4706... Generator Loss: 0.7196
# Epoch 1/1... Discriminator Loss: 1.4629... Generator Loss: 0.7049
# Epoch 1/1... Discriminator Loss: 1.5637... Generator Loss: 0.8796
# Epoch 1/1... Discriminator Loss: 1.4791... Generator Loss: 1.0505
# Epoch 1/1... Discriminator Loss: 1.5068... Generator Loss: 0.8592
# Epoch 1/1... Discriminator Loss: 1.5465... Generator Loss: 1.1328
# Epoch 1/1... Discriminator Loss: 1.4479... Generator Loss: 0.6347
# Epoch 1/1... Discriminator Loss: 1.4433... Generator Loss: 0.5493
# Epoch 1/1... Discriminator Loss: 1.4728... Generator Loss: 0.4427
# Epoch 1/1... Discriminator Loss: 1.5114... Generator Loss: 0.4276
# Epoch 1/1... Discriminator Loss: 1.5093... Generator Loss: 0.3978
# Epoch 1/1... Discriminator Loss: 1.4578... Generator Loss: 0.5924
# Epoch 1/1... Discriminator Loss: 1.5472... Generator Loss: 1.0844
# Epoch 1/1... Discriminator Loss: 1.5031... Generator Loss: 1.0296
# Epoch 1/1... Discriminator Loss: 1.3392... Generator Loss: 0.7723
# Epoch 1/1... Discriminator Loss: 1.4354... Generator Loss: 1.0522
# Epoch 1/1... Discriminator Loss: 1.4236... Generator Loss: 0.6878

# %% [markdown]
# ### CelebA
# Run your GANs on CelebA.  It will take around 20 minutes on the average GPU to run one epoch.  You can run the whole epoch or stop when it starts to generate realistic faces.

# %%
batch_size = 128
z_dim = 100
learning_rate = 0.001
beta1 = 0.3


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 1.1018... Generator Loss: 23.5159
# Epoch 1/2... Discriminator Loss: 3.7822... Generator Loss: 0.0513
# Epoch 1/2... Discriminator Loss: 3.1050... Generator Loss: 0.0875
# Epoch 1/2... Discriminator Loss: 1.6186... Generator Loss: 2.0695
# Epoch 1/2... Discriminator Loss: 1.7253... Generator Loss: 1.1074
# Epoch 1/2... Discriminator Loss: 1.7485... Generator Loss: 1.3495
# Epoch 1/2... Discriminator Loss: 2.1210... Generator Loss: 1.6847
# Epoch 1/2... Discriminator Loss: 1.8487... Generator Loss: 0.3915
# Epoch 1/2... Discriminator Loss: 1.6353... Generator Loss: 0.4798
# Epoch 1/2... Discriminator Loss: 1.5826... Generator Loss: 0.6145
# Epoch 1/2... Discriminator Loss: 1.5729... Generator Loss: 0.6023
# Epoch 1/2... Discriminator Loss: 1.5207... Generator Loss: 0.6681
# Epoch 1/2... Discriminator Loss: 1.5200... Generator Loss: 0.6487
# Epoch 1/2... Discriminator Loss: 1.4533... Generator Loss: 0.6623
# Epoch 1/2... Discriminator Loss: 1.5941... Generator Loss: 0.5604
# Epoch 1/2... Discriminator Loss: 1.4315... Generator Loss: 0.6472
# Epoch 1/2... Discriminator Loss: 1.4537... Generator Loss: 0.6787
# Epoch 1/2... Discriminator Loss: 1.5682... Generator Loss: 0.5923
# Epoch 1/2... Discriminator Loss: 1.6403... Generator Loss: 0.6190
# Epoch 1/2... Discriminator Loss: 1.4591... Generator Loss: 0.6167
# Epoch 1/2... Discriminator Loss: 1.5472... Generator Loss: 0.6532
# Epoch 1/2... Discriminator Loss: 1.4859... Generator Loss: 0.6755
# Epoch 1/2... Discriminator Loss: 1.4563... Generator Loss: 0.7578
# Epoch 1/2... Discriminator Loss: 1.4789... Generator Loss: 0.6662
# Epoch 1/2... Discriminator Loss: 1.4717... Generator Loss: 0.6037
# Epoch 1/2... Discriminator Loss: 1.4912... Generator Loss: 0.6324
# Epoch 1/2... Discriminator Loss: 1.4727... Generator Loss: 0.6442
# Epoch 1/2... Discriminator Loss: 1.4601... Generator Loss: 0.6296
# Epoch 1/2... Discriminator Loss: 1.5473... Generator Loss: 0.6207
# Epoch 1/2... Discriminator Loss: 1.4370... Generator Loss: 0.6542
# Epoch 1/2... Discriminator Loss: 1.4065... Generator Loss: 0.6420
# Epoch 1/2... Discriminator Loss: 1.5197... Generator Loss: 0.6299
# Epoch 1/2... Discriminator Loss: 1.5315... Generator Loss: 0.5652
# Epoch 1/2... Discriminator Loss: 1.4667... Generator Loss: 0.6132
# Epoch 1/2... Discriminator Loss: 1.4732... Generator Loss: 0.6417
# Epoch 1/2... Discriminator Loss: 1.4312... Generator Loss: 0.6302
# Epoch 1/2... Discriminator Loss: 1.4198... Generator Loss: 0.6848
# Epoch 1/2... Discriminator Loss: 1.4569... Generator Loss: 0.6579
# Epoch 1/2... Discriminator Loss: 1.5002... Generator Loss: 0.7034
# Epoch 1/2... Discriminator Loss: 1.4660... Generator Loss: 0.7037
# Epoch 1/2... Discriminator Loss: 1.5558... Generator Loss: 0.6477
# Epoch 1/2... Discriminator Loss: 1.4775... Generator Loss: 0.7887
# Epoch 1/2... Discriminator Loss: 1.4368... Generator Loss: 0.6378
# Epoch 1/2... Discriminator Loss: 1.4642... Generator Loss: 0.7427
# Epoch 1/2... Discriminator Loss: 1.4396... Generator Loss: 0.6895
# Epoch 1/2... Discriminator Loss: 1.4806... Generator Loss: 0.6791
# Epoch 1/2... Discriminator Loss: 1.4380... Generator Loss: 0.6142
# Epoch 1/2... Discriminator Loss: 1.5452... Generator Loss: 0.5976
# Epoch 1/2... Discriminator Loss: 1.4436... Generator Loss: 0.6345
# Epoch 1/2... Discriminator Loss: 1.4911... Generator Loss: 0.7648
# Epoch 1/2... Discriminator Loss: 1.4730... Generator Loss: 0.6241
# Epoch 1/2... Discriminator Loss: 1.4238... Generator Loss: 0.5946
# Epoch 1/2... Discriminator Loss: 1.4811... Generator Loss: 0.6603
# Epoch 1/2... Discriminator Loss: 1.4846... Generator Loss: 0.6023
# Epoch 1/2... Discriminator Loss: 1.4731... Generator Loss: 0.6739
# Epoch 1/2... Discriminator Loss: 1.4786... Generator Loss: 0.6817
# Epoch 1/2... Discriminator Loss: 1.4336... Generator Loss: 0.7383
# Epoch 1/2... Discriminator Loss: 1.4495... Generator Loss: 0.7494
# Epoch 1/2... Discriminator Loss: 1.4325... Generator Loss: 0.6114
# Epoch 1/2... Discriminator Loss: 1.4289... Generator Loss: 0.6229
# Epoch 1/2... Discriminator Loss: 1.4103... Generator Loss: 0.7041
# Epoch 1/2... Discriminator Loss: 1.4628... Generator Loss: 0.7157
# Epoch 1/2... Discriminator Loss: 1.4309... Generator Loss: 0.7724
# Epoch 1/2... Discriminator Loss: 1.4435... Generator Loss: 0.6519
# Epoch 1/2... Discriminator Loss: 1.4414... Generator Loss: 0.6032
# Epoch 1/2... Discriminator Loss: 1.6195... Generator Loss: 0.6276
# Epoch 1/2... Discriminator Loss: 1.5025... Generator Loss: 0.6144
# Epoch 1/2... Discriminator Loss: 1.4530... Generator Loss: 0.6685
# Epoch 1/2... Discriminator Loss: 1.4580... Generator Loss: 0.6481
# Epoch 1/2... Discriminator Loss: 1.4402... Generator Loss: 0.6540
# Epoch 1/2... Discriminator Loss: 1.4737... Generator Loss: 0.7308
# Epoch 1/2... Discriminator Loss: 1.4699... Generator Loss: 0.7320
# Epoch 1/2... Discriminator Loss: 1.4537... Generator Loss: 0.6121
# Epoch 1/2... Discriminator Loss: 1.4779... Generator Loss: 0.7039
# Epoch 1/2... Discriminator Loss: 1.4402... Generator Loss: 0.6627
# Epoch 1/2... Discriminator Loss: 1.4626... Generator Loss: 0.5931
# Epoch 1/2... Discriminator Loss: 1.4380... Generator Loss: 0.6789
# Epoch 1/2... Discriminator Loss: 1.5382... Generator Loss: 0.5975
# Epoch 1/2... Discriminator Loss: 1.4349... Generator Loss: 0.7352
# Epoch 1/2... Discriminator Loss: 1.4430... Generator Loss: 0.6086
# Epoch 1/2... Discriminator Loss: 1.4336... Generator Loss: 0.6596
# Epoch 1/2... Discriminator Loss: 1.4358... Generator Loss: 0.6996
# Epoch 1/2... Discriminator Loss: 1.4707... Generator Loss: 0.7414
# Epoch 1/2... Discriminator Loss: 1.4831... Generator Loss: 0.6995
# Epoch 1/2... Discriminator Loss: 1.4669... Generator Loss: 0.6115
# Epoch 1/2... Discriminator Loss: 1.4431... Generator Loss: 0.7777
# Epoch 1/2... Discriminator Loss: 1.4674... Generator Loss: 0.6795
# Epoch 1/2... Discriminator Loss: 1.4374... Generator Loss: 0.6027
# Epoch 1/2... Discriminator Loss: 1.4170... Generator Loss: 0.6103
# Epoch 1/2... Discriminator Loss: 1.4233... Generator Loss: 0.6469
# Epoch 1/2... Discriminator Loss: 1.4406... Generator Loss: 0.7441
# Epoch 1/2... Discriminator Loss: 1.4143... Generator Loss: 0.6631
# Epoch 1/2... Discriminator Loss: 1.4667... Generator Loss: 0.6519
# Epoch 1/2... Discriminator Loss: 1.4425... Generator Loss: 0.6841
# Epoch 1/2... Discriminator Loss: 1.4329... Generator Loss: 0.6607
# Epoch 1/2... Discriminator Loss: 1.4413... Generator Loss: 0.6646
# Epoch 1/2... Discriminator Loss: 1.4556... Generator Loss: 0.7105
# Epoch 1/2... Discriminator Loss: 1.4285... Generator Loss: 0.6951
# Epoch 1/2... Discriminator Loss: 1.4038... Generator Loss: 0.6991
# Epoch 1/2... Discriminator Loss: 1.4120... Generator Loss: 0.6708
# Epoch 1/2... Discriminator Loss: 1.4533... Generator Loss: 0.5813
# Epoch 1/2... Discriminator Loss: 1.5084... Generator Loss: 0.6488
# Epoch 1/2... Discriminator Loss: 1.4856... Generator Loss: 0.6113
# Epoch 1/2... Discriminator Loss: 1.4383... Generator Loss: 0.7151
# Epoch 1/2... Discriminator Loss: 1.4821... Generator Loss: 0.7752
# Epoch 1/2... Discriminator Loss: 1.4478... Generator Loss: 0.6934
# Epoch 1/2... Discriminator Loss: 1.3839... Generator Loss: 0.7438
# Epoch 1/2... Discriminator Loss: 1.4214... Generator Loss: 0.5977
# Epoch 1/2... Discriminator Loss: 1.4904... Generator Loss: 0.6108
# Epoch 1/2... Discriminator Loss: 1.4329... Generator Loss: 0.5868
# Epoch 1/2... Discriminator Loss: 1.4006... Generator Loss: 0.6755
# Epoch 1/2... Discriminator Loss: 1.4312... Generator Loss: 0.7029
# Epoch 1/2... Discriminator Loss: 1.4445... Generator Loss: 0.7325
# Epoch 1/2... Discriminator Loss: 1.4193... Generator Loss: 0.6522
# Epoch 1/2... Discriminator Loss: 1.5185... Generator Loss: 0.8634
# Epoch 1/2... Discriminator Loss: 1.4326... Generator Loss: 0.6634
# Epoch 1/2... Discriminator Loss: 1.4280... Generator Loss: 0.5923
# Epoch 1/2... Discriminator Loss: 1.4204... Generator Loss: 0.6366
# Epoch 1/2... Discriminator Loss: 1.4151... Generator Loss: 0.6311
# Epoch 1/2... Discriminator Loss: 1.3975... Generator Loss: 0.7296
# Epoch 1/2... Discriminator Loss: 1.4274... Generator Loss: 0.7337
# Epoch 1/2... Discriminator Loss: 1.4117... Generator Loss: 0.5729
# Epoch 1/2... Discriminator Loss: 1.4580... Generator Loss: 0.6337
# Epoch 1/2... Discriminator Loss: 1.4675... Generator Loss: 0.7655
# Epoch 1/2... Discriminator Loss: 1.4635... Generator Loss: 0.6836
# Epoch 1/2... Discriminator Loss: 1.4280... Generator Loss: 0.7865
# Epoch 1/2... Discriminator Loss: 1.4385... Generator Loss: 0.5779
# Epoch 1/2... Discriminator Loss: 1.4388... Generator Loss: 0.7557
# Epoch 1/2... Discriminator Loss: 1.4039... Generator Loss: 0.7925
# Epoch 1/2... Discriminator Loss: 1.4554... Generator Loss: 0.6229
# Epoch 1/2... Discriminator Loss: 1.3811... Generator Loss: 0.6862
# Epoch 1/2... Discriminator Loss: 1.4655... Generator Loss: 0.6957
# Epoch 1/2... Discriminator Loss: 1.4075... Generator Loss: 0.7169
# Epoch 1/2... Discriminator Loss: 1.4580... Generator Loss: 0.7876
# Epoch 1/2... Discriminator Loss: 1.4408... Generator Loss: 0.6139
# Epoch 1/2... Discriminator Loss: 1.4417... Generator Loss: 0.7326
# Epoch 1/2... Discriminator Loss: 1.4353... Generator Loss: 0.6893
# Epoch 1/2... Discriminator Loss: 1.4519... Generator Loss: 0.5630
# Epoch 1/2... Discriminator Loss: 1.4096... Generator Loss: 0.6760
# Epoch 1/2... Discriminator Loss: 1.4035... Generator Loss: 0.6508
# Epoch 1/2... Discriminator Loss: 1.4738... Generator Loss: 0.6599
# Epoch 1/2... Discriminator Loss: 1.4238... Generator Loss: 0.6140
# Epoch 1/2... Discriminator Loss: 1.4189... Generator Loss: 0.6774
# Epoch 1/2... Discriminator Loss: 1.3996... Generator Loss: 0.6285
# Epoch 1/2... Discriminator Loss: 1.4117... Generator Loss: 0.7249
# Epoch 1/2... Discriminator Loss: 1.4275... Generator Loss: 0.7562
# Epoch 1/2... Discriminator Loss: 1.4208... Generator Loss: 0.6723
# Epoch 1/2... Discriminator Loss: 1.4283... Generator Loss: 0.6228
# Epoch 1/2... Discriminator Loss: 1.3917... Generator Loss: 0.7494
# Epoch 1/2... Discriminator Loss: 1.4262... Generator Loss: 0.7014
# Epoch 1/2... Discriminator Loss: 1.3928... Generator Loss: 0.6740
# Epoch 1/2... Discriminator Loss: 1.4215... Generator Loss: 0.7025
# Epoch 1/2... Discriminator Loss: 1.4203... Generator Loss: 0.7513
# Epoch 1/2... Discriminator Loss: 1.5038... Generator Loss: 0.6038
# Epoch 1/2... Discriminator Loss: 1.3858... Generator Loss: 0.7286
# Epoch 1/2... Discriminator Loss: 1.4314... Generator Loss: 0.7693
# Epoch 1/2... Discriminator Loss: 1.4126... Generator Loss: 0.7101
# Epoch 1/2... Discriminator Loss: 1.4231... Generator Loss: 0.6874
# Epoch 2/2... Discriminator Loss: 1.4112... Generator Loss: 0.6216
# Epoch 2/2... Discriminator Loss: 1.3954... Generator Loss: 0.6877
# Epoch 2/2... Discriminator Loss: 1.4332... Generator Loss: 0.6325
# Epoch 2/2... Discriminator Loss: 1.3980... Generator Loss: 0.6909
# Epoch 2/2... Discriminator Loss: 1.4438... Generator Loss: 0.5668
# Epoch 2/2... Discriminator Loss: 1.4416... Generator Loss: 0.7061
# Epoch 2/2... Discriminator Loss: 1.4339... Generator Loss: 0.5383
# Epoch 2/2... Discriminator Loss: 1.3773... Generator Loss: 0.6856
# Epoch 2/2... Discriminator Loss: 1.4006... Generator Loss: 0.6782
# Epoch 2/2... Discriminator Loss: 1.4057... Generator Loss: 0.6663
# Epoch 2/2... Discriminator Loss: 1.4699... Generator Loss: 0.6291
# Epoch 2/2... Discriminator Loss: 1.4240... Generator Loss: 0.6512
# Epoch 2/2... Discriminator Loss: 1.4126... Generator Loss: 0.7620
# Epoch 2/2... Discriminator Loss: 1.4248... Generator Loss: 0.7019
# Epoch 2/2... Discriminator Loss: 1.4444... Generator Loss: 0.6313
# Epoch 2/2... Discriminator Loss: 1.4961... Generator Loss: 0.7423
# Epoch 2/2... Discriminator Loss: 1.4262... Generator Loss: 0.7666
# Epoch 2/2... Discriminator Loss: 1.4854... Generator Loss: 0.5013
# Epoch 2/2... Discriminator Loss: 1.4860... Generator Loss: 0.6567
# Epoch 2/2... Discriminator Loss: 1.4152... Generator Loss: 0.5782
# Epoch 2/2... Discriminator Loss: 1.4681... Generator Loss: 0.6300
# Epoch 2/2... Discriminator Loss: 1.4083... Generator Loss: 0.6625
# Epoch 2/2... Discriminator Loss: 1.4419... Generator Loss: 0.5593
# Epoch 2/2... Discriminator Loss: 1.3982... Generator Loss: 0.6895
# Epoch 2/2... Discriminator Loss: 1.4011... Generator Loss: 0.7093
# Epoch 2/2... Discriminator Loss: 1.4283... Generator Loss: 0.6977
# Epoch 2/2... Discriminator Loss: 1.4316... Generator Loss: 0.6450
# Epoch 2/2... Discriminator Loss: 1.4409... Generator Loss: 0.5428
# Epoch 2/2... Discriminator Loss: 1.4371... Generator Loss: 0.7072
# Epoch 2/2... Discriminator Loss: 1.4272... Generator Loss: 0.6265
# Epoch 2/2... Discriminator Loss: 1.5153... Generator Loss: 0.7092
# Epoch 2/2... Discriminator Loss: 1.4379... Generator Loss: 0.7971
# Epoch 2/2... Discriminator Loss: 1.4454... Generator Loss: 0.6287
# Epoch 2/2... Discriminator Loss: 1.4211... Generator Loss: 0.7016
# Epoch 2/2... Discriminator Loss: 1.4622... Generator Loss: 0.6300
# Epoch 2/2... Discriminator Loss: 1.4065... Generator Loss: 0.7231
# Epoch 2/2... Discriminator Loss: 1.4649... Generator Loss: 0.6928
# Epoch 2/2... Discriminator Loss: 1.4518... Generator Loss: 0.6718
# Epoch 2/2... Discriminator Loss: 1.4405... Generator Loss: 0.6763
# Epoch 2/2... Discriminator Loss: 1.4202... Generator Loss: 0.7337
# Epoch 2/2... Discriminator Loss: 1.4234... Generator Loss: 0.6046
# Epoch 2/2... Discriminator Loss: 1.3977... Generator Loss: 0.6797
# Epoch 2/2... Discriminator Loss: 1.4749... Generator Loss: 0.5895
# Epoch 2/2... Discriminator Loss: 1.4239... Generator Loss: 0.7695
# Epoch 2/2... Discriminator Loss: 1.4032... Generator Loss: 0.6226
# Epoch 2/2... Discriminator Loss: 1.4102... Generator Loss: 0.7563
# Epoch 2/2... Discriminator Loss: 1.4177... Generator Loss: 0.7564
# Epoch 2/2... Discriminator Loss: 1.4061... Generator Loss: 0.7199
# Epoch 2/2... Discriminator Loss: 1.4104... Generator Loss: 0.5591
# Epoch 2/2... Discriminator Loss: 1.4103... Generator Loss: 0.7054
# Epoch 2/2... Discriminator Loss: 1.4127... Generator Loss: 0.5824
# Epoch 2/2... Discriminator Loss: 1.4073... Generator Loss: 0.7171
# Epoch 2/2... Discriminator Loss: 1.4126... Generator Loss: 0.6172
# Epoch 2/2... Discriminator Loss: 1.4462... Generator Loss: 0.6892
# Epoch 2/2... Discriminator Loss: 1.3900... Generator Loss: 0.7209
# Epoch 2/2... Discriminator Loss: 1.4852... Generator Loss: 0.5915
# Epoch 2/2... Discriminator Loss: 1.4460... Generator Loss: 0.6518
# Epoch 2/2... Discriminator Loss: 1.4923... Generator Loss: 0.6343
# Epoch 2/2... Discriminator Loss: 1.4156... Generator Loss: 0.6473
# Epoch 2/2... Discriminator Loss: 1.4106... Generator Loss: 0.7539
# Epoch 2/2... Discriminator Loss: 1.4447... Generator Loss: 0.5998
# Epoch 2/2... Discriminator Loss: 1.4089... Generator Loss: 0.7018
# Epoch 2/2... Discriminator Loss: 1.3713... Generator Loss: 0.6026
# Epoch 2/2... Discriminator Loss: 1.4018... Generator Loss: 0.6912
# Epoch 2/2... Discriminator Loss: 1.3925... Generator Loss: 0.7291
# Epoch 2/2... Discriminator Loss: 1.4105... Generator Loss: 0.6383
# Epoch 2/2... Discriminator Loss: 1.4832... Generator Loss: 0.7641
# Epoch 2/2... Discriminator Loss: 1.4223... Generator Loss: 0.6605
# Epoch 2/2... Discriminator Loss: 1.4392... Generator Loss: 0.7785
# Epoch 2/2... Discriminator Loss: 1.4166... Generator Loss: 0.6921
# Epoch 2/2... Discriminator Loss: 1.4054... Generator Loss: 0.7105
# Epoch 2/2... Discriminator Loss: 1.4139... Generator Loss: 0.6218
# Epoch 2/2... Discriminator Loss: 1.4092... Generator Loss: 0.6770
# Epoch 2/2... Discriminator Loss: 1.4322... Generator Loss: 0.7568
# Epoch 2/2... Discriminator Loss: 1.4371... Generator Loss: 0.5922
# Epoch 2/2... Discriminator Loss: 1.4068... Generator Loss: 0.6175
# Epoch 2/2... Discriminator Loss: 1.4494... Generator Loss: 0.6879
# Epoch 2/2... Discriminator Loss: 1.4084... Generator Loss: 0.7050
# Epoch 2/2... Discriminator Loss: 1.4158... Generator Loss: 0.7926
# Epoch 2/2... Discriminator Loss: 1.4431... Generator Loss: 0.6357
# Epoch 2/2... Discriminator Loss: 1.4311... Generator Loss: 0.5736
# Epoch 2/2... Discriminator Loss: 1.4273... Generator Loss: 0.6389
# Epoch 2/2... Discriminator Loss: 1.4471... Generator Loss: 0.6974
# Epoch 2/2... Discriminator Loss: 1.4137... Generator Loss: 0.6770
# Epoch 2/2... Discriminator Loss: 1.4660... Generator Loss: 0.6723
# Epoch 2/2... Discriminator Loss: 1.4039... Generator Loss: 0.7521
# Epoch 2/2... Discriminator Loss: 1.3979... Generator Loss: 0.7084
# Epoch 2/2... Discriminator Loss: 1.4324... Generator Loss: 0.7963
# Epoch 2/2... Discriminator Loss: 1.4094... Generator Loss: 0.7196
# Epoch 2/2... Discriminator Loss: 1.4302... Generator Loss: 0.6690
# Epoch 2/2... Discriminator Loss: 1.4063... Generator Loss: 0.6533
# Epoch 2/2... Discriminator Loss: 1.4130... Generator Loss: 0.7235
# Epoch 2/2... Discriminator Loss: 1.4329... Generator Loss: 0.7059
# Epoch 2/2... Discriminator Loss: 1.4244... Generator Loss: 0.6225
# Epoch 2/2... Discriminator Loss: 1.4353... Generator Loss: 0.6754
# Epoch 2/2... Discriminator Loss: 1.4532... Generator Loss: 0.6542
# Epoch 2/2... Discriminator Loss: 1.4568... Generator Loss: 0.6324
# Epoch 2/2... Discriminator Loss: 1.4690... Generator Loss: 0.6372
# Epoch 2/2... Discriminator Loss: 1.4037... Generator Loss: 0.7292
# Epoch 2/2... Discriminator Loss: 1.5001... Generator Loss: 0.5315
# Epoch 2/2... Discriminator Loss: 1.4318... Generator Loss: 0.6276
# Epoch 2/2... Discriminator Loss: 1.4215... Generator Loss: 0.7392
# Epoch 2/2... Discriminator Loss: 1.4154... Generator Loss: 0.5764
# Epoch 2/2... Discriminator Loss: 1.4249... Generator Loss: 0.7056
# Epoch 2/2... Discriminator Loss: 1.4351... Generator Loss: 0.6540
# Epoch 2/2... Discriminator Loss: 1.4431... Generator Loss: 0.6821
# Epoch 2/2... Discriminator Loss: 1.4642... Generator Loss: 0.6898
# Epoch 2/2... Discriminator Loss: 1.4097... Generator Loss: 0.6963
# Epoch 2/2... Discriminator Loss: 1.4522... Generator Loss: 0.6642
# Epoch 2/2... Discriminator Loss: 1.4171... Generator Loss: 0.6241
# Epoch 2/2... Discriminator Loss: 1.4515... Generator Loss: 0.7965
# Epoch 2/2... Discriminator Loss: 1.3991... Generator Loss: 0.7435
# Epoch 2/2... Discriminator Loss: 1.4241... Generator Loss: 0.6192
# Epoch 2/2... Discriminator Loss: 1.3855... Generator Loss: 0.7542
# Epoch 2/2... Discriminator Loss: 1.4118... Generator Loss: 0.6757
# Epoch 2/2... Discriminator Loss: 1.3982... Generator Loss: 0.6752
# Epoch 2/2... Discriminator Loss: 1.4203... Generator Loss: 0.7171
# Epoch 2/2... Discriminator Loss: 1.4113... Generator Loss: 0.6450
# Epoch 2/2... Discriminator Loss: 1.4106... Generator Loss: 0.6634
# Epoch 2/2... Discriminator Loss: 1.4101... Generator Loss: 0.7018
# Epoch 2/2... Discriminator Loss: 1.4281... Generator Loss: 0.7153
# Epoch 2/2... Discriminator Loss: 1.4359... Generator Loss: 0.5767
# Epoch 2/2... Discriminator Loss: 1.4322... Generator Loss: 0.5763
# Epoch 2/2... Discriminator Loss: 1.3958... Generator Loss: 0.6165
# Epoch 2/2... Discriminator Loss: 1.4057... Generator Loss: 0.6318
# Epoch 2/2... Discriminator Loss: 1.4154... Generator Loss: 0.6789
# Epoch 2/2... Discriminator Loss: 1.4010... Generator Loss: 0.6283
# Epoch 2/2... Discriminator Loss: 1.4322... Generator Loss: 0.6835
# Epoch 2/2... Discriminator Loss: 1.4347... Generator Loss: 0.7401
# Epoch 2/2... Discriminator Loss: 1.4192... Generator Loss: 0.6646
# Epoch 2/2... Discriminator Loss: 1.3944... Generator Loss: 0.7172
# Epoch 2/2... Discriminator Loss: 1.4354... Generator Loss: 0.6394
# Epoch 2/2... Discriminator Loss: 1.4021... Generator Loss: 0.7598
# Epoch 2/2... Discriminator Loss: 1.4029... Generator Loss: 0.7034
# Epoch 2/2... Discriminator Loss: 1.4070... Generator Loss: 0.6055
# Epoch 2/2... Discriminator Loss: 1.4056... Generator Loss: 0.7414
# Epoch 2/2... Discriminator Loss: 1.4089... Generator Loss: 0.6577
# Epoch 2/2... Discriminator Loss: 1.4142... Generator Loss: 0.5363
# Epoch 2/2... Discriminator Loss: 1.4038... Generator Loss: 0.7034
# Epoch 2/2... Discriminator Loss: 1.4115... Generator Loss: 0.6978
# Epoch 2/2... Discriminator Loss: 1.4102... Generator Loss: 0.7329
# Epoch 2/2... Discriminator Loss: 1.4311... Generator Loss: 0.6485
# Epoch 2/2... Discriminator Loss: 1.4436... Generator Loss: 0.7283
# Epoch 2/2... Discriminator Loss: 1.3935... Generator Loss: 0.6249
# Epoch 2/2... Discriminator Loss: 1.4599... Generator Loss: 0.6528
# Epoch 2/2... Discriminator Loss: 1.3820... Generator Loss: 0.6527
# Epoch 2/2... Discriminator Loss: 1.4307... Generator Loss: 0.7088
# Epoch 2/2... Discriminator Loss: 1.4396... Generator Loss: 0.6868
# Epoch 2/2... Discriminator Loss: 1.4000... Generator Loss: 0.6005
# Epoch 2/2... Discriminator Loss: 1.4322... Generator Loss: 0.6298
# Epoch 2/2... Discriminator Loss: 1.4294... Generator Loss: 0.6543
# Epoch 2/2... Discriminator Loss: 1.3986... Generator Loss: 0.6841
# Epoch 2/2... Discriminator Loss: 1.4388... Generator Loss: 0.7060
# Epoch 2/2... Discriminator Loss: 1.4223... Generator Loss: 0.6166
# Epoch 2/2... Discriminator Loss: 1.4017... Generator Loss: 0.6617
# Epoch 2/2... Discriminator Loss: 1.4021... Generator Loss: 0.6455
# Epoch 2/2... Discriminator Loss: 1.4592... Generator Loss: 0.6842
# Epoch 2/2... Discriminator Loss: 1.4077... Generator Loss: 0.6444

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
